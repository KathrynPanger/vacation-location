# %%
# Dependencies
import requests
import json
from citipy import citipy
import numpy as np
from config import owkey
import geoip2.database
import geoip2.webservice
import pandas as pd
import random
import time
import matplotlib.pyplot as plt
from scipy.stats import sem
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm
import gmaps
from config import gkey
import pprint
import time

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# geocoordinates
target_coordinates = "37.7749,-122.4194" 
target_radius = 80
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()

# %%
response
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '7156529684800805c139910e627ebc55b0b26084',
#    'name': 'São Francisco',
#    'place_id': 'ChIJdQE2nESBhYAR6DNrfVlhS2M',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJdQE2nESBhYAR6DNrfVlhS2M',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '8844f0c898c57bf3e61bf11132ec60c136ed273f',
#    'name': 'Cartwight Hotel San Francisco',
#    'place_id': 'ChIJMX2T3qGBhYARTU7fLfnnTAc',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJMX2T3qGBhYARTU7fLfnnTAc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Cartwight Hotel, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '475bccf7eaec4a2d05a722a2f040d71f9e71cd50',
#    'name': 'Santa Rosa CA',
#    'place_id': 'ChIJaRsnlnyBhYARXAiNrwD9ATc',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJaRsnlnyBhYARXAiNrwD9ATc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7763749802915,
#       'lng': -122.4180263697085},
#      'southwest': {'lat': 37.7736770197085, 'lng': -122.4207243302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b3cf815b8ab07ce63ffda3b853104a8e35bc803f',
#    'name': 'SFO',
#    'place_id': 'ChIJEYwgvDuBhYAR2c8egfJX-7w',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJEYwgvDuBhYAR2c8egfJX-7w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'SFLO, Van Ness Avenue, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'e64ec069362d99d5a2d07f39ad32f618df8dc936',
#    'name': 'Sur Carolina',
#    'place_id': 'ChIJ5263SImBhYARZGgBrEW81-o',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJ5263SImBhYARZGgBrEW81-o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd44c0f4ed1a9b50071d98f707bd717919ec6622f',
#    'name': 'Intercâmbio',
#    'place_id': 'ChIJRS8xLAiBhYAR99yR9PoK7QE',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJRS8xLAiBhYAR99yR9PoK7QE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '151c11d9a231d56b2c64c5c61149df9be3a1c1ed',
#    'name': 'Hôtel ambassy',
#    'place_id': 'ChIJGY56JpCBhYARi6lRPUg_8-E',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJGY56JpCBhYARi6lRPUg_8-E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Embassy hotel, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7763107802915,
#       'lng': -122.4181074697085},
#      'southwest': {'lat': 37.7736128197085, 'lng': -122.4208054302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '75928ed09722091ad7b73c5d99a064e0e172c73b',
#    'name': 'Artmar',
#    'place_id': 'ChIJ0f5mcwiBhYARF7NVLDUv0rs',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJ0f5mcwiBhYARF7NVLDUv0rs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '1525 Market Street, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762882302915,
#       'lng': -122.4180045197085},
#      'southwest': {'lat': 37.7735902697085, 'lng': -122.4207024802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'bf82dbeb2429fffc907ddc08fd0985398c34428b',
#    'name': 'Stanford court',
#    'place_id': 'ChIJ93-huh2BhYARNrDFjIr3hXk',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJ93-huh2BhYARNrDFjIr3hXk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '59-11 U.S. 101, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'db87243c12f8f923a91c4447eba81125bd39062e',
#    'name': 'San Francisco',
#    'place_id': 'ChIJDQ2qd3-BhYARJE-VfXficpc',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJDQ2qd3-BhYARJE-VfXficpc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'viewport': {'northeast': {'lat': 37.7762784802915,
#       'lng': -122.4180665197085},
#      'southwest': {'lat': 37.7735805197085, 'lng': -122.4207644802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '14224892140c221db5b6dea06955df9f062d0129',
#    'name': 'Hotel vintage court',
#    'place_id': 'ChIJS6_CwVuBhYARn0nWM9kn2hs',
#    'plus_code': {'compound_code': 'QHFJ+X6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+X6'},
#    'reference': 'ChIJS6_CwVuBhYARn0nWM9kn2hs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7748673, 'lng': -122.4193928},
#     'viewport': {'northeast': {'lat': 37.7762162802915,
#       'lng': -122.4180438197085},
#      'southwest': {'lat': 37.7735183197085, 'lng': -122.4207417802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '8a638ef19c79a7c7d0ac9437d7f563ec3877ad5c',
#    'name': 'Hotel Cliff ,495',
#    'place_id': 'ChIJEdGJjp6AhYAR7vDSiD6IvcQ',
#    'plus_code': {'compound_code': 'QHFJ+W6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+W6'},
#    'reference': 'ChIJEdGJjp6AhYAR7vDSiD6IvcQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7748673, 'lng': -122.4193928},
#     'viewport': {'northeast': {'lat': 37.7762162802915,
#       'lng': -122.4180438197085},
#      'southwest': {'lat': 37.7735183197085, 'lng': -122.4207417802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ed69dc8a50a433566862f54843b9577442f9dc9a',
#    'name': 'Hotel SF',
#    'place_id': 'ChIJEdGJjp6AhYARtghd0dUyJo4',
#    'plus_code': {'compound_code': 'QHFJ+W6 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+W6'},
#    'reference': 'ChIJEdGJjp6AhYARtghd0dUyJo4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Distrito, 1599 Lombard Street, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.77487199999999, 'lng': -122.4195699},
#     'viewport': {'northeast': {'lat': 37.7762709302915,
#       'lng': -122.4181704697085},
#      'southwest': {'lat': 37.7735729697085, 'lng': -122.4208684302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b35549ed83441101c7f1061004205c53eb59781a',
#    'name': 'Sunnyside hotel',
#    'place_id': 'ChIJEdGJjp6AhYARGGjCkxZJfas',
#    'plus_code': {'compound_code': 'QHFJ+W5 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+W5'},
#    'rating': 5,
#    'reference': 'ChIJEdGJjp6AhYARGGjCkxZJfas',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '8411 Market Street, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.77487199999999, 'lng': -122.4195699},
#     'viewport': {'northeast': {'lat': 37.7762709302915,
#       'lng': -122.4181704697085},
#      'southwest': {'lat': 37.7735729697085, 'lng': -122.4208684302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9214c443cccd39db3411b56ae9f031a94dfce735',
#    'name': 'Handles hotel',
#    'place_id': 'ChIJEdGJjp6AhYARTXZd0G9hOig',
#    'plus_code': {'compound_code': 'QHFJ+W5 SoMa, San Francisco, CA, USA',
#     'global_code': '849VQHFJ+W5'},
#    'reference': 'ChIJEdGJjp6AhYARTXZd0G9hOig',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '8411 Market Street, San Francisco'}],
#  'status': 'OK'}

# %%
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
